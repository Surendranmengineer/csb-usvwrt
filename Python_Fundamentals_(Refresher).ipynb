# %% [markdown]
# <a href="https://colab.research.google.com/github/Surendranmengineer/csb-usvwrt/blob/gh-pages/Python_Fundamentals_(Refresher).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Fundamentals
# ---

# %% [markdown]
# objective: to refresh our concepts on basic input / output + decision Making
# ---

# %% [markdown]
# Objective: ask the user to enter the basic Pay ,
# <pre>
# if basicPay <=5000 , then calculate HRA as 16% of basicPay , and DA as 14% of basicPay
#
# if basicPay >5000, then Caclulate HRA as 12% of basicPay and DA as 10% of basicPay
#
# find gross Pay i.e. sum of basicPay + HRA + DA

# %%
basicPay = int (input('enter basic pay 💴 '))

if basicPay > 5000 :

  HRA= .12 * basicPay
  DA = .1  * basicPay

else:

  HRA = .16 * basicPay
  DA  = .14 * basicPay

# let us find the grossPay

grossPay = basicPay + HRA + DA

# let us use string formatting using F-String to print the salary details

salarySummary =f'''
-------------------------Salary Slip -----------------
BasicPay : {basicPay}
HRA     :  {HRA}
DA      :  {DA}
-------------------
Gross :    {grossPay}
'''

print( salarySummary )
# Out:
# enter basic pay 💴 9000
#
# -------------------------Salary Slip -----------------
# BasicPay : 9000
# HRA     :  1080.0
# DA      :  900.0
# -------------------
# Gross :    10980.0

# %%
round(1.123456,2)
# Out:
# 1.12

# %% [markdown]
# # Quick Activity:
#
# this activity validates your Looping Skills
# ---
